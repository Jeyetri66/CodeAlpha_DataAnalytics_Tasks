# %% [markdown]
# TASK 2: Exploratory Data Analysis (EDA)
#
# Questions:
#
# Who scored the highest and lowest marks?
# What is the average marks of students?
# Is there any difference between male and female performance?
# Are there any missing values in the dataset?
# Are there any unusual or extreme values?

# %%
import pandas as pd

data = {
    "Name": ["A", "B", "C", "D"],
    "Marks": [85, 90, 78, 92],
    "Gender": ["M", "F", "M", "F"]
}

df = pd.DataFrame(data)

print("Dataset:\n", df)
print("\nData Info:\n")
print(df.info())
print("\nStatistical Summary:\n", df.describe())
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Dataset:
#    Name  Marks Gender
# 0    A     85      M
# 1    B     90      F
# 2    C     78      M
# 3    D     92      F
#
# Data Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Marks   4 non-null      int64
#  2   Gender  4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None
#
# Statistical Summary:
#             Marks
# count   4.000000
# mean   86.250000
# std     6.238322
# min    78.000000
# 25%    83.250000
# 50%    87.500000
# 75%    90.500000
# max    92.000000
#
# Missing Values:
#  Name      0
# Marks     0
# Gender    0
# dtype: int64

# %%
print("Highest Marks:", df["Marks"].max())
print("Lowest Marks:", df["Marks"].min())

print("\nAverage Marks:", df["Marks"].mean())

print("\nAverage Marks by Gender:\n", df.groupby("Gender")["Marks"].mean())
# Out:
# Highest Marks: 92
# Lowest Marks: 78
#
# Average Marks: 86.25
#
# Average Marks by Gender:
#  Gender
# F    91.0
# M    81.5
# Name: Marks, dtype: float64

# %%
male_avg = df[df["Gender"] == "M"]["Marks"].mean()
female_avg = df[df["Gender"] == "F"]["Marks"].mean()

print("Male Average Marks:", male_avg)
print("Female Average Marks:", female_avg)
# Out:
# Male Average Marks: 81.5
# Female Average Marks: 91.0

# %%
print("Missing Values:\n", df.isnull().sum())
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Missing Values:
#  Name      0
# Marks     0
# Gender    0
# dtype: int64
# Duplicate Rows: 0

# %% [markdown]
# Analysis & Insights:
#
# Student D has the highest marks (92), while Student C has the lowest (78).
# The average marks of students is approximately 86.
# Female students have slightly higher average marks compared to male students.
# There are no missing values or duplicate records in the dataset.
# No extreme or abnormal values are observed.
# Conclusion:
#
# The dataset is clean and well-structured. There is a slight trend showing female students performing better than male students. Overall performance is consistent across students.
